# %% [markdown]
# 1. Binary Search:

# %% [markdown]
# note1:Try to find out best way possible
# note2:Use names in camel case or like that avoid a and b type names.
# note3:Try to check if the code is covering all code cases use input and output example accordingly
# note4:
